# %% [markdown]
# This is a code to build a email classifier which learns from emails distinct pattern and classify it either postive or negative.
# We build multiple  models for it and choose the best one

# %%
# Natural Language Processing

# Importing the libraries
import pandas as pd
import pickle as pkl
import numpy as np
import matplotlib.pyplot as plt
#from sklearn.metrics import roc_curve, auc

# Importing the dataset
dataset = pd.read_csv('Opportunities - Sheet1.tsv', delimiter = '\t')

# %%
dataset['Replies'].tail()
# Out:
# 1159                Good Morning Benjamin,  I have spo...
# 1160                You’ll have to be more specific so...
# 1161              I am not using Metasys-I have previo...
# 1162                 We are a manufacturing facility w...
# 1163         I am not interested.  Thanks.  PaulFrom: ...
# Name: Replies, dtype: object

# %%
# Cleaning the texts
import re
from nltk.stem.snowball import SnowballStemmer

# %%
#Unpickle stopwords
with open("Stopwords.pickle","rb") as stop_file:
    stop = pkl.load(stop_file)

# %%
stop
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doing',
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'nor',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she's",
#  'should',
#  "should've",
#  'shouldn',
#  "shouldn't",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  'were',
#  'weren',
#  "weren't",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %%
stop = stop - set(('yes','no','not','don\'t','aren\'t','isn\'t','doesn\'t','isn','aren','don','doesn'))

# %%
ss = SnowballStemmer("english")

# %%
corpus = []
for i in range(0,len(dataset)):
    review = re.sub('[^a-zA-Z]', ' ', dataset['Replies'][i])
    review = review.lower()
    review = review.split()
    review = [ss.stem(word) for word in review if not word in set(stop)]
    review = ' '.join(review)
    corpus.append(review)

# %%
corpus
# Out:
# ['securus contact system not securus payment see email domain name thank steven lemma ceowww securuscontactsystem comsent iphon pleas excus error oct ron smith lt ron smith marketjoy com gt wrote sorri jeff copi thank ron smith ron smith sent monday octob steven lemma scs subject x securus payment sale minut hi steven thank get back us copi colleagu jeff burn email would right person answer question ron smith steven lemma scs lt steven securuscontactsystem com gt sent friday octob pm ron smith subject x securus payment sale minut cost first program saw websit thank steven lemma ceo www securuscontactsystem com sent iphon pleas excus error oct pm lt ron smith marketjoy com gt lt ron smith marketjoy com gt wrote hi steven hope great name ron marketjoy idea explain minutesthat getsecurus payment next custom recent use process help clientviachem aspecialtychem andingredi distributor almost tripl month revenu assur servic abl help salesteam close deal creat strong sale pipelin predict revenu would like share idea best practic seen work competitor aren theappropri person don mind point right direct would great appreci help thank ron smith marketjoy inc phone www marketjoy com click link stop receiv mail ron smith marketjoy com unsubscrib',
#  'unsubscrib cheer dave dave kranowitz gm amp vp enterpris sale america email dave kranowitz turbonom com offic ron smith mailto ron smith marketjoy com sent tuesday octob dave kranowitz lt dave kranowitz turbonom com gt subject x turbonom inc traction minut hi dave want follow email would tuesday wednesday work quick call discuss thank ron smith ron smith sent thursday octob dave kranowitz turbonom com subject x turbonom inc traction minut hi dave want follow email would tuesday wednesday work quick call discuss thank ron smith ron smith sent thursday septemb dave kranowitz turbonom com subject x turbonom inc traction minut hi dave hope great name ron marketjoy idea explain minut getturbonomicit next custom recent use process help client viachem speaklik wealthhub solut almost tripl month run rate assur servic abl help team close deal creat strong sale pipelin predict revenu better roi would like share idea best practic seen work compani like pleas let know suitabl time per avail send calendar invit aren appropri person don mind point right direct would great appreci help thank ron smith marketjoy inc phone www marketjoy com may repli email let know not want receiv futur email messag attach intend design recipi may contain confidenti proprietari inform may subject legal confidenti protect not design recipi may not review copi distribut messag receiv error pleas notifi sender repli e mail delet messag thank',
#  'hi share inform market director interest reach warm cherylcheryl buckdirector busi develop america prmia prmia membership set profession apart identifi activ growth promot risk profess demonstr leadership help fellow risk practition develop best practic employe communiti becom leader join prmia provid expertis join today atwww prmia org email attach use individu entiti address inform without prejudic view individu not necessarili organ email attach may contain inform legal privileg confidenti exempt disclosur not intend recipi herebi notifi dissemin distribut copi communic attach strict prohibit receiv email error pleas notifi system manag tue oct ron smith lt ron smith marketjoy com gt wrote hi cheryl hear back make sens talk let know calendar look thank ron smith ron smith sent thursday octob cheryl buck prmia org subject x prmia traction minut hi cheryl want follow email would tuesday wednesday work quick call discuss thank ron smith ron smith sent thursday septemb cheryl buck prmia org subject x prmia traction minut hi cheryl hope great name ron marketjoy idea explain minut getprmiait next custom recent use process help client viachem speaklik wealthhub solut almost tripl month run rate assur servic abl help team close deal creat strong sale pipelin predict revenu better roi would like share idea best practic seen work compani like pleas let know suitabl time per avail send calendar invit aren appropri person don mind point right direct would great appreci help thank ron smith marketjoy inc phone www marketjoy
best custom recent use process help client cpn almost tripl month run rate know servic abl help team close deal creat strong sale pipelin predict revenu love get feedback even not market right min want set quick call discuss servic might abl help let know question sorri unsolicit email regard ray marshallwww saleszip comclick link stop receiv mail ray saleszip com unsubscrib',
#  'not interest pleas remov liston thu dec ray marshal lt ray saleszip com gt wrote hi jeff want follow email would next week wednesday thursday work quick call discuss thank rayon wed nov pm lt ray saleszip com gt wrote hi jeff hope don mind reach like name ray co founder saleszip saleszip new concept industri sale servic help compani reach futur custom today work top player tech financ industri idea explain minut get plan pod next best custom recent use process help client cpn almost tripl month run rate know servic abl help team close deal creat strong sale pipelin predict revenu love get feedback even not market right min want set quick call discuss servic might abl help let know question sorri unsolicit email regard ray marshallwww saleszip comclick link stop receiv mail ray saleszip com unsubscrib jeff kear owner plan pod jeff planningpod comhttp www planningpod com follow plan pod linkedin http www linkedin com compani facebook https www facebook com planningpodgoogl https plus googl com twitter https twitter com planpod sent gmail mobil',
#  ...]

# %%
# Creating the Bag of Words model
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features = 1500)
X = cv.fit_transform(corpus).toarray()
y = dataset.iloc[:, 1].values
feature_names = cv.get_feature_names()

# %%
feature_names
# Out:
# ['aaalif',
#  'abdul',
#  'abil',
#  'abl',
#  'abm',
#  'abril',
#  'accept',
#  'access',
#  'accompani',
#  'account',
#  'accuraci',
#  'accuzip',
#  'across',
#  'act',
#  'action',
#  'activ',
#  'actual',
#  'ad',
#  'adam',
#  'addit',
#  'address',
#  'addresse',
#  'administr',
#  'advanc',
#  'advantag',
#  'advantagesystemsinc',
#  'advic',
#  'advis',
#  'advisor',
#  'adwizar',
#  'affili',
#  'afternoon',
#  'ag',
#  'agenc',
#  'agencyspark',
#  'agent',
#  'aggress',
#  'agreement',
#  'ai',
#  'alan',
#  'alert',
#  'alex',
#  'alexand',
#  'allen',
#  'allianc',
#  'allow',
#  'allur',
#  'allurecar',
#  'almost',
#  'along',
#  'alphapoint',
#  'alphasoftwar',
#  'alreadi',
#  'also',
#  'although',
#  'alway',
#  'america',
#  'american',
#  'americasbestfranchis',
#  'ami',
#  'amount',
#  'amp',
#  'amto',
#  'analysi',
#  'andi',
#  'andrew',
#  'angel',
#  'anita',
#  'ann',
#  'anoth',
#  'anthoni',
#  'anyon',
#  'anyth',
#  'anytim',
#  'aperiom',
#  'apex',
#  'apexllc',
#  'apolog',
#  'app',
#  'appli',
#  'applic',
#  'applicast',
#  'appoint',
#  'appreci',
#  'approach',
#  'appropri',
#  'architect',
#  'architectur',
#  'archiv',
#  'archiverphon',
#  'area',
#  'aren',
#  'aris',
#  'aron',
#  'around',
#  'arriv',
#  'ash',
#  'ask',
#  'aspecialtychemicalandingredi',
#  'assess',
#  'asset',
#  'assetvu',
#  'assist',
#  'associ',
#  'assur',
#  'atlanta',
#  'atom',
#  'attach',
#  'attorney',
#  'audit',
#  'austin',
#  'author',
#  'autom',
#  'autopitch',
#  'avail',
#  'avast',
#  'ave',
#  'avenu',
#  'awar',
#  'award',
#  'ayoub',
#  'babel',
#  'babelhealth',
#  'back',
#  'bado',
#  'bailey',
#  'baker',
#  'bank',
#  'barbara',
#  'barcod',
#  'barn',
#  'base',
#  'bc',
#  'bdd',
#  'beach',
#  'beechler',
#  'believ',
#  'ben',
#  'bendt',
#  'bene',
#  'benefit',
#  'benjamin',
#  'best',
#  'better',
#  'bhrlrgkoxad',
#  'bi',
#  'big',
#  'bill',
#  'billion',
#  'binger',
#  'bingerfinanci',
#  'bishop',
#  'bit',
#  'blanchard',
#  'ble',
#  'blog',
#  'bluefox',
#  'bluepay',
#  'bluetooth',
#  'blvd',
#  'board',
#  'bob',
#  'bodi',
#  'boss',
#  'bother',
#  'box',
#  'bqg',
#  'bracket',
#  'brad',
#  'bradley',
#  'branch',
#  'brand',
#  'brandon',
#  'brdt',
#  'breed',
#  'brent',
#  'brian',
#  'bridg',
#  'brief',
#  'brill',
#  'bring',
#  'broker',
#  'brook',
#  'broughton',
#  'brown',
#  'bruce',
#  'bryce',
#  'buchanan',
#  'budget',
#  'build',
#  'builder',
#  'burden',
#  'burn',
#  'busi',
#  'buy',
#  'ca',
#  'cad',
#  'calendar',
#  'california',
#  'call',
#  'callianc',
#  'canada',
#  'candid',
#  'cannot',
#  'capac',
#  'capit',
#  'card',
#  'care',
#  'career',
#  'carissa',
#  'carl',
#  'case',
#  'cassetta',
#  'castl',
#  'caus',
#  'caution',
#  'caze',
#  'cc',
#  'ccbb',
#  'cdt',
#  'cell',
#  'cem',
#  'center',
#  'central',
#  'ceo',
#  'certain',
#  'cf',
#  'cfde',
#  'ch',
#  'challeng',
#  'chanc',
#  'chang',
#  'changehealthcar',
#  'charl',
#  'charlton',
#  'chat',
#  'check',
#  'cheer',
#  'chellamuthu',
#  'chemic',
#  'chicago',
#  'chief',
#  'choic',
#  'choos',
#  'chris',
#  'christian',
#  'circl',
#  'citi',
#  'claim',
#  'class',
#  'clean',
#  'clear',
#  'click',
#  'client',
#  'clientviachem',
#  'clinic',
#  'close',
#  'cloud',
#  'co',
#  'code',
#  'collabor',
#  'colleagu',
#  'collect',
#  'colleen',
#  'colleend',
#  'colleg',
#  'com',
#  'comclick',
#  'come',
#  'comfrom',
#  'commit',
#  'communic',
#  'communiti',
#  'comon',
#  'compani',
#  'competitor',
#  'complet',
#  'complianc',
#  'compris',
#  'comput',
#  'comscor',
#  'comskyp',
#  'comstay',
#  'comsubject',
#  'comunsubscrib',
#  'comwww',
#  'concept',
#  'conduct',
#  'confidenti',
#  'connect',
#  'consent',
#  'consid',
#  'constitut',
#  'construct',
#  'consult',
#  'consum',
#  'contact',
#  'contain',
#  'content',
#  'contract',
#  'control',
#  'convers',
#  'convert',
#  'cooper',
#  'coordin',
#  'coordinatorharmoni',
#  'copi',
#  'copyright',
#  'core',
#  'corp',
#  'corpor',
#  'correct',
#  'corrupt',
#  'cost',
#  'cotter',
#  'could',
#  'counti',
#  'coupl',
#  'cover',
#  'cpn',
#  'craig',
#  'creat',
#  'creativ',
#  'credit',
#  'critic',
#  'crowdz',
#  'cryptowerk',
#  'ct',
#  'culmin',
#  'current',
#  'curti',
#  'custom',
#  'cut',
#  'cycl',
#  'daili',
#  'dalla',
#  'dalton',
#  'damag',
#  'dan',
#  'daniel',
#  'data',
#  'datacenterrfid',
#  'date',
#  'dave',
#  'david',
#  'dawn',
#  'day',
#  'dazze',
#  'dbridg',
#  'dc',
#  'de',
#  'deal',
#  'dean',
#  'deana',
#  'dear',
#  'debbi',
#  'dec',
#  'decemb',
#  'decim',
#  'decis',
#  'decommiss',
#  'definit',
#  'delet',
#  'deliv',
#  'deliveri',
#  'demo',
#  'denis',
#  'denni',
#  'depart',
#  'deploy',
#  'derbyshir',
#  'design',
#  'destroy',
#  'detail',
#  'determin',
#  'develop',
#  'devic',
#  'dgreen',
#  'dial',
#  'dictat',
#  'differ',
#  'digit',
#  'dinfotech',
#  'direct',
#  'director',
#  'disclaim',
#  'disclos',
#  'disclosur',
#  'discuss',
#  'dissemin',
#  'distribut',
#  'distributor',
#  'divis',
#  'doc',
#  'document',
#  'doesn',
#  'dollar',
#  'don',
#  'donald',
#  'done',
#  'donington',
#  'dr',
#  'dresher',
#  'drive',
#  'drop',
#  'druva',
#  'dustin',
#  'duvt',
#  'earli',
#  'earlier',
#  'east',
#  'eastern',
#  'eddi',
#  'edg',
#  'edt',
#  'edu',
#  'edward',
#  'ehr',
#  'either',
#  'ele',
#  'electron',
#  'elimin',
#  'ell',
#  'elli',
#  'email',
#  'emo',
#  'empinfo',
#  'employ',
#  'employe',
#  'emr',
#  'en',
#  'enabl',
#  'end',
#  'endodontist',
#  'energi',
#  'engag',
#  'engin',
#  'england',
#  'enough',
#  'ensur',
#  'enterpris',
#  'entir',
#  'entiti',
#  'environ',
#  'equip',
#  'eric',
#  'erp',
#  'error',
#  'est',
#  'establish',
#  'et',
#  'etc',
#  'evan',
#  'even',
#  'event',
#  'everi',
#  'everyth',
#  'exceed',
#  'excel',
#  'exclus',
#  'excus',
#  'execut',
#  'exempt',
#  'expect',
#  'expens',
#  'experi',
#  'expert',
#  'explain',
#  'explor',
#  'express',
#  'ext',
#  'extern',
#  'extract',
#  'fabsuit',
#  'face',
#  'facebook',
#  'facil',
#  'fals',
#  'fapp',
#  'farm',
#  'faster',
#  'fastest',
#  'favour',
#  'fax',
#  'featur',
#  'feb',
#  'februari',
#  'feder',
#  'feedback',
#  'feel',
#  'fenley',
#  'fetchrev',
#  'field',
#  'fifteen',
#  'file',
#  'fill',
#  'final',
#  'financ',
#  'financi',
#  'find',
#  'findex',
#  'finra',
#  'firm',
#  'first',
#  'fit',
#  'fl',
#  'floor',
#  'fmailact',
#  'fmsgid',
#  'focus',
#  'folkman',
#  'follow',
#  'followup',
#  'form',
#  'fort',
#  'forward',
#  'found',
#  'founder',
#  'franchis',
#  'frank',
#  'free',
#  'fri',
#  'friday',
#  'fridaywork',
#  'fromron',
#  'front',
#  'frustrat',
#  'full',
#  'function',
#  'fund',
#  'futur',
#  'fw',
#  'ga',
#  'gap',
#  'gari',
#  'garon',
#  'garrett',
#  'gb',
#  'gelli',
#  'gen',
#  'generat',
#  'genium',
#  'geoff',
#  'geoffrey',
#  'georg',
#  'geraci',
#  'get',
#  'girl',
#  'girlscoutsindiana',
#  'give',
#  'glenn',
#  'global',
#  'gmt',
#  'go',
#  'goal',
#  'golf',
#  'gontier',
#  'good',
#  'goodman',
#  'googl',
#  'got',
#  'gov',
#  'graphic',
#  'great',
#  'green',
#  'greet',
#  'greg',
#  'gregori',
#  'gretchen',
#  'ground',
#  'group',
#  'grow',
#  'growth',
#  'gruettner',
#  'gt',
#  'gtms',
#  'guarante',
#  'guarino',
#  'guy',
#  'gym',
#  'ha',
#  'hall',
#  'handl',
#  'handshakeclick',
#  'happi',
#  'hard',
#  'harmoni',
#  'harmonyhit',
#  'harri',
#  'hcahealthcar',
#  'head',
#  'health',
#  'healthcar',
#  'hear',
#  'heard',
#  'hello',
#  'help',
#  'henri',
#  'herebi',
#  'herein',
#  'hey',
#  'hi',
#  'high',
#  'higher',
#  'hire',
#  'hit',
#  'holiday',
#  'home',
#  'hop',
#  'hope',
#  'hornor',
#  'horsham',
#  'hospit',
#  'hour',
#  'hous',
#  'houston',
#  'howev',
#  'hr',
#  'htk',
#  'http',
#  'https',
#  'hugu',
#  'human',
#  'hundr',
#  'hybrid',
#  'ia',
#  'ibeacon',
#  'id',
#  'idea',
#  'identifi',
#  'il',
#  'imag',
#  'imail',
#  'immedi',
#  'import',
#  'improv',
#  'inadvert',
#  'inbox',
#  'inc',
#  'includ',
#  'incomplet',
#  'incphon',
#  'increas',
#  'indiana',
#  'individu',
#  'industri',
#  'info',
#  'inform',
#  'informedwebsit',
#  'infotech',
#  'infrastructur',
#  'initi',
#  'innov',
#  'insight',
#  'instal',
#  'institut',
#  'instruct',
#  'insur',
#  'integr',
#  'intellig',
#  'intend',
#  'interact',
#  'intercept',
#  'interest',
#  'interlac',
#  'intern',
#  'interview',
#  'introductori',
#  'inventori',
#  'invest',
#  'investor',
#  'invit',
#  'involv',
#  'io',
#  'iphon',
#  'iphoneon',
#  'issu',
#  'item',
#  'jack',
#  'jackson',
#  'jag',
#  'jame',
#  'jan',
#  'januari',
#  'jar',
#  'jare',
#  'jason',
#  'jbiancucci',
#  'jd',
#  'jdipietro',
#  'jeff',
#  'jeffrey',
#  'jen',
#  'jennif',
#  'jensen',
#  'jim',
#  'jnobl',
#  'job',
#  'joe',
#  'joel',
#  'john',
#  'johnclick',
#  'johnson',
#  'join',
#  'jon',
#  'josh',
#  'joy',
#  'juli',
#  'june',
#  'justin',
#  'justyn',
#  'jw',
#  'jwilson',
#  'karen',
#  'karla',
#  'kayla',
#  'kcaze',
#  'keep',
#  'keith',
#  'ken',
#  'kennedi',
#  'kenneth',
#  'kent',
#  'kevin',
#  'khayyam',
#  'kim',
#  'kimberton',
#  'kind',
#  'kirkland',
#  'know',
#  'kodak',
#  'kori',
#  'kpischk',
#  'ktgi',
#  'kurt',
#  'labor',
#  'landscap',
#  'larg',
#  'last',
#  'late',
#  'later',
#  'latest',
#  'launch',
#  'laura',
#  'lauri',
#  'law',
#  'layout',
#  'lead',
#  'leadership',
#  'learn',
#  'lee',
#  'legaci',
#  'legal',
#  'leonovus',
#  'lesli',
#  'let',
#  'level',
#  'liabil',
#  'liberti',
#  'licens',
#  'life',
#  'like',
#  'limit',
#  'linda',
#  'line',
#  'link',
#  'linkedin',
#  'linkedr',
#  'list',
#  'littl',
#  'live',
#  'livio',
#  'llc',
#  'llcclick',
#  'llp',
#  'lmahoney',
#  'locat',
#  'logist',
#  'london',
#  'long',
#  'longer',
#  'look',
#  'lost',
#  'lot',
#  'love',
#  'low',
#  'lt',
#  'ltd',
#  'luck',
#  'lui',
#  'made',
#  'madison',
#  'mahoney',
#  'mail',
#  'mailto',
#  'main',
#  'maintain',
#  'mainten',
#  'make',
#  'maker',
#  'manag',
#  'managementhi',
#  'mani',
#  'mar',
#  'marc',
#  'march',
#  'mari',
#  'mario',
#  'mark',
#  'market',
#  'marketjoy',
#  'marshal',
#  'marshallwww',
#  'martin',
#  'martinez',
#  'materi',
#  'matt',
#  'matthew',
#  'mauricio',
#  'may',
#  'mayb',
#  'mccormack',
#  'mckesson',
#  'mean',
#  'media',
#  'medic',
#  'meet',
#  'melissa',
#  'member',
#  'memori',
#  'mention',
#  'meridian',
#  'messag',
#  'metric',
#  'mfenley',
#  'michael',
#  'michaeldavidwineri',
#  'michigan',
#  'mickey',
#  'mid',
#  'might',
#  'mike',
#  'miller',
#  'miln',
#  'min',
#  'mind',
#  'mine',
#  'minut',
#  'minuteshi',
#  'minutesthat',
#  'miss',
#  'mission',
#  'mistak',
#  'mn',
#  'mo',
#  'mobil',
#  'mobilestorm',
#  'model',
#  'moment',
#  'momentum',
#  'mon',
#  'monday',
#  'money',
#  'monitor',
#  'monster',
#  'monsterindia',
#  'month',
#  'morn',
#  'move',
#  'much',
#  'multi',
#  'mumbai',
#  'must',
#  'mutual',
#  'mzero',
#  'na',
#  'name',
#  'nandakumar',
#  'nanopay',
#  'nate',
#  'nation',
#  'natur',
#  'navi',
#  'nc',
#  'nd',
#  'ndot',
#  'ne',
#  'necessari',
#  'necessarili',
#  'need',
#  'net',
#  'netsubject',
#  'network',
#  'never',
#  'new',
#  'newberri',
#  'newer',
#  'newforma',
#  'news',
#  'next',
#  'nice',
#  'nkgio',
#  'no',
#  'noah',
#  'nobl',
#  'nomin',
#  'non',
#  'none',
#  'normal',
#  'north',
#  'northridg',
#  'not',
#  'note',
#  'notic',
#  'notifi',
#  'nov',
#  'novemb',
#  'number',
#  'nw',
#  'ny',
#  'obes',
#  'obesityppm',
#  'oblig',
#  'ocontain',
#  'oct',
#  'octob',
#  'offer',
#  'offic',
#  'ofhealthdataarchiv',
#  'oildex',
#  'ok',
#  'old',
#  'oliv',
#  'omiss',
#  'one',
#  'oneclearview',
#  'onlin',
#  'onlinkedin',
#  'ooptim',
#  'open',
#  'oper',
#  'opinion',
#  'opow',
#  'opportun',
#  'option',
#  'orais',
#  'oral',
#  'order',
#  'org',
#  'organ',
#  'orient',
#  'origin',
#  'orwednesday',
#  'other',
#  'otherwis',
#  'outbound',
#  'outlook',
#  'outreach',
#  'outsid',
#  'outsourc',
#  'owner',
#  'oxygen',
#  'pa',
#  'pacif',
#  'pamela',
#  'panason',
#  'park',
#  'part',
#  'parti',
#  'particip',
#  'partner',
#  'parwinr',
#  'pass',
#  'passiv',
#  'past',
#  'patient',
#  'patrick',
#  'paul',
#  'payment',
#  'payrol',
#  'payson',
#  'pc',
#  'peerpilot',
#  'peopl',
#  'per',
#  'perform',
#  'perman',
#  'persist',
#  'person',
#  'personalcapit',
#  'personto',
#  'peter',
#  'peterson',
#  'pettit',
#  'ph',
#  'phi',
#  'phoenixvill',
#  'phone',
#  'pii',
#  'pine',
#  ...]

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection  import train_test_split
from sklearn.metrics import confusion_matrix,roc_curve, auc
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 0)

from sklearn.ensemble import BaggingClassifier, AdaBoostClassifier, VotingClassifier

######################Model Building######################
# Fitting Naive Bayes 
from sklearn.naive_bayes import GaussianNB
classifier_nb = GaussianNB()
classifier_nb.fit(X_train, y_train)
y_pred_log2 = classifier_nb.predict(X_test)
cm_log2 = confusion_matrix(y_test, y_pred_log2)
#a1= classifier_nb.score(X_train,y_train)
#b1=classifier_nb.score(X_test,y_test)
print(cm_log2)

#ROC Curve
y_prob_nb = classifier_nb.predict_proba(X_test)[:,1] # This will give you positive class prediction probabilities  
y_pred_nb = np.where(y_prob_nb > 0.5, 1, 0) # This will threshold the probabilities to give class predictions.

X_test.shape[0]
(y_test!= y_pred_nb).sum()

false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_prob_nb)
roc_auc = auc(false_positive_rate, true_positive_rate)

plt.figure(figsize=(10,10))
plt.title('Receiver Operating Characteristic')
plt.plot(false_positive_rate,true_positive_rate, color='blue',label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],linestyle='--')
plt.axis('tight')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
# Out:
# [[116  63]
#  [ 17  37]]
# Text(0.5, 0, 'False Positive Rate')

# %%
#Fitting SVM
from sklearn.svm import SVC
classifier_svm = SVC()
classifier_svm.fit(X_train, y_train)
y_pred_log3 = classifier_svm.predict(X_test)
cm_log3 = confusion_matrix(y_test, y_pred_log3)
print (cm_log3)
#a2=classifier_ksvm.score(X_train,y_train)


print (classifier_svm.score(X_test,y_test))

#ROC Curve
y_prob_svm = classifier_svm.predict(X_test) # This will give you positive class prediction probabilities  
y_pred_svm = np.where(y_prob_svm > 0.5, 1, 0) # This will threshold the probabilities to give class predictions.

false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_prob_svm)
roc_auc = auc(false_positive_rate, true_positive_rate)

plt.figure(figsize=(10,10))
plt.title('Receiver Operating Characteristic')
plt.plot(false_positive_rate,true_positive_rate, color='blue',label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],linestyle='--')
plt.axis('tight')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
# Out:
# C:\Users\rahul\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# [[176   3]
#  [ 44  10]]
# 0.7982832618025751
# Text(0.5, 0, 'False Positive Rate')

# %%
#Fitting SVM
from sklearn import metrics
from sklearn.svm import SVC
classifier_ksvm = SVC(kernel = 'rbf', random_state = 0, C=1500, gamma=0.001)
classifier_ksvm.fit(X_train, y_train)
y_pred_log4_1 = classifier_ksvm.predict(X_test)
cm_log4_1 = confusion_matrix(y_test, y_pred_log4_1)

print (cm_log4_1)

print (classifier_ksvm.score(X_test,y_test))
#a3=classifier_svm.score(X_train,y_train)
#b3=classifier_svm.score(X_test,y_test)

#ROC Curve
y_prob_svm = classifier_ksvm.predict(X_test) # This will give you positive class prediction probabilities  
y_pred_svm = np.where(y_prob_svm > 0.5, 1, 0) # This will threshold the probabilities to give class predictions.

false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_prob_svm)
roc_auc = auc(false_positive_rate, true_positive_rate)

plt.figure(figsize=(10,10))
plt.title('Receiver Operating Characteristic')
plt.plot(false_positive_rate,true_positive_rate, color='blue',label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],linestyle='--')
plt.axis('tight')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
# Out:
# [[161  18]
#  [ 19  35]]
# 0.8412017167381974
# Text(0.5, 0, 'False Positive Rate')

# %% [markdown]
# Here we see Kernel SVM is giving best result as compared to SVM and Naives' Bayes. Linear SVM has perfomed the worst of all.
# Lets try few more algorithms.

# %%
#Fitting Logistic Regression
from sklearn.metrics import confusion_matrix
from sklearn.linear_model import LogisticRegression
classifier_log = LogisticRegression(random_state = 0)
classifier_log.fit(X_train, y_train)
y_pred_log = classifier_log.predict(X_test)
cm_log = confusion_matrix(y_test, y_pred_log)
#a4=classifier_log.score(X_train,y_train)
print(classifier_log.score(X_test,y_test))
print (cm_log)

#ROC Curve
y_prob = classifier_log.predict_proba(X_test)[:,1] # This will give you positive class prediction probabilities  
y_pred = np.where(y_prob > 0.5, 1, 0) # This will threshold the probabilities to give class predictions.

false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(false_positive_rate, true_positive_rate)
roc_auc

plt.figure(figsize=(10,10))
plt.title('Receiver Operating Characteristic')
plt.plot(false_positive_rate,true_positive_rate, color='red',label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],linestyle='--')
plt.axis('tight')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
# Out:
# 0.871244635193133
# [[168  11]
#  [ 19  35]]
# C:\Users\rahul\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Text(0.5, 0, 'False Positive Rate')

# %%
#Here we see logistic regression has really outperformed all of them by a huge margin. Although accuracy of KSVM & Logistic
# Regression is not much different (84 % vs 87 %). But as AUC score is 90 %, we see that it is neither overfitting or 
#biased

# %%
from sklearn.tree import DecisionTreeClassifier
decision = DecisionTreeClassifier()
decision.fit(X_train, y_train)
y_pred_log6 = decision.predict(X_test)
cm_log6 = confusion_matrix(y_test, y_pred_log6)

print (decision.score(X_test,y_test))
#a6=decision.score(X_train,y_train)
#b6=decision.score(X_test,y_test)

print (cm_log6)

#ROC Curve
y_prob = decision.predict_proba(X_test)[:,1] # This will give you positive class prediction probabilities  
y_pred = np.where(y_prob > 0.5, 1, 0) # This will threshold the probabilities to give class predictions.

false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(false_positive_rate, true_positive_rate)
roc_auc

plt.figure(figsize=(10,10))
plt.title('Receiver Operating Characteristic')
plt.plot(false_positive_rate,true_positive_rate, color='red',label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],linestyle='--')
plt.axis('tight')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
# Out:
# 0.8412017167381974
# [[163  16]
#  [ 21  33]]
# Text(0.5, 0, 'False Positive Rate')

# %%
#Fitting RandomForest
from sklearn.ensemble import RandomForestClassifier
regressor = RandomForestClassifier(n_estimators = 20)
regressor.fit(X_train, y_train)
y_pred_log5 = regressor.predict(X_test)
cm_log5 = confusion_matrix(y_test, y_pred_log5)
#a5=regressor.score(X_train,y_train)
print (regressor.score(X_test,y_test))

print (cm_log5)

#ROC Curve
y_prob = regressor.predict_proba(X_test)[:,1] # This will give you positive class prediction probabilities  
y_pred = np.where(y_prob > 0.5, 1, 0) # This will threshold the probabilities to give class predictions.

false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(false_positive_rate, true_positive_rate)
roc_auc

plt.figure(figsize=(10,10))
plt.title('Receiver Operating Characteristic')
plt.plot(false_positive_rate,true_positive_rate, color='red',label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],linestyle='--')
plt.axis('tight')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
# Out:
# 0.8197424892703863
# [[174   5]
#  [ 37  17]]
# Text(0.5, 0, 'False Positive Rate')

# %%
######################Bagging######################
bg = BaggingClassifier(classifier_svm, max_samples= 0.5, max_features = 1.0)
bg.fit(X_train,y_train)
y_pred_log9 = bg.predict(X_test)
cm_log9 = confusion_matrix(y_test, y_pred_log9)
#print('1',bg.score(X_train,y_train))
#print('1', bg.score(X_test,y_test))

y_prob = bg.predict_proba(X_test)[:,1] # This will give you positive class prediction probabilities  
y_pred = np.where(y_prob > 0.5, 1, 0) # This will threshold the probabilities to give class predictions.

false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(false_positive_rate, true_positive_rate)
print (roc_auc)

plt.figure(figsize=(10,10))
plt.title('Receiver Operating Characteristic')
plt.plot(false_positive_rate,true_positive_rate, color='red',label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],linestyle='--')
plt.axis('tight')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
# Out:
# C:\Users\rahul\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\rahul\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\rahul\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\rahul\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\rahul\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\rahul\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\rahul\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\rahul\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\rahul\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\rahul\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# 0.59579971032485
# Text(0.5, 0, 'False Positive Rate')

# %%
#Bagging for decision tree
bg = BaggingClassifier(decision, max_samples= 0.5, max_features = 1.0, n_estimators = 20)
bg.fit(X_train,y_train)
y_pred_log10 = bg.predict(X_test)
cm_log10 = confusion_matrix(y_test, y_pred_log10)
print('1',bg.score(X_train,y_train))# Overfitting on training data
print('1', bg.score(X_test,y_test))

y_prob = bg.predict_proba(X_test)[:,1] # This will give you positive class prediction probabilities  
y_pred = np.where(y_prob > 0.5, 1, 0) # This will threshold the probabilities to give class predictions.

false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(false_positive_rate, true_positive_rate)
print (roc_auc)

plt.figure(figsize=(10,10))
plt.title('Receiver Operating Characteristic')
plt.plot(false_positive_rate,true_positive_rate, color='red',label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],linestyle='--')
plt.axis('tight')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
# Out:
# 1 0.9430719656283566
# 1 0.871244635193133
# 0.8500413821642872
# Text(0.5, 0, 'False Positive Rate')

# %%
# See how a poor performing decision tree is able to minmize it's error using bagging and reach the accuracy level and AUC score
# of one of the highest.

# %%
#####################Boosting - Ada Boost######################
adb = AdaBoostClassifier(classifier_svm,n_estimators = 5, learning_rate = 1, algorithm='SAMME')
adb.fit(X_train,y_train)
y_pred_log11 = classifier_svm.predict(X_test)
cm_log11 = confusion_matrix(y_test, y_pred_log11)

print (cm_log11)


print('1',adb.score(X_train,y_train))
print('1',adb.score(X_test,y_test))

adb = AdaBoostClassifier(classifier_ksvm,n_estimators = 5, learning_rate = 1, algorithm='SAMME')
adb.fit(X_train,y_train)
y_pred_log12 = classifier_ksvm.predict(X_test)
cm_log12 = confusion_matrix(y_test, y_pred_log12)


print (cm_log11)

print('2',adb.score(X_train,y_train))
print('2',adb.score(X_test,y_test))

#ROC Curve
y_prob_svm_ada = adb.predict(X_test) # This will give you positive class prediction probabilities  
y_pred_svm_ada = np.where(y_prob_svm_ada > 0.5, 1, 0) # This will threshold the probabilities to give class predictions.

X_test.shape[0]
(y_test!= y_pred_svm_ada).sum()

false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_prob_svm_ada)
roc_auc = auc(false_positive_rate, true_positive_rate)
roc_auc

plt.figure(figsize=(10,10))
plt.title('Receiver Operating Characteristic')
plt.plot(false_positive_rate,true_positive_rate, color='green',label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],linestyle='--')
plt.axis('tight')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
# Out:
# C:\Users\rahul\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\rahul\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\rahul\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\rahul\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# [[176   3]
#  [ 44  10]]
# 1 0.7110633727175081
# 1 0.7682403433476395
# [[176   3]
#  [ 44  10]]
# 2 0.8421052631578947
# 2 0.7982832618025751
# Text(0.5, 0, 'False Positive Rate')

# %%
# Boosting was not particularly helpful here.

# %%
########################## Voting Classifier - Multiple Model Ensemble######################
nb = classifier_nb
lr = classifier_log
dt = decision
svm = classifier_svm
ksvm = classifier_ksvm
#svm = SVC(kernel = 'poly', degree = 2 )
evc = VotingClassifier( estimators= [('lr',lr),('dt',dt),('svm',svm),('ksvm',ksvm)], voting = 'hard')
evc.fit(X_train,y_train)
#evc.fit(x_train.iloc[1:4000],y_train.iloc[1:4000])
evc.score(X_train,y_train)
evc.score(X_test,y_test)

#ROC Curve
y_prob_svm_ada = evc.predict(X_test) # This will give you positive class prediction probabilities  
y_pred_svm_ada = np.where(y_prob_svm_ada > 0.5, 1, 0) # This will threshold the probabilities to give class predictions.

X_test.shape[0]
(y_test!= y_pred_svm_ada).sum()

false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_prob_svm_ada)
roc_auc = auc(false_positive_rate, true_positive_rate)
roc_auc

plt.figure(figsize=(10,10))
plt.title('Receiver Operating Characteristic')
plt.plot(false_positive_rate,true_positive_rate, color='green',label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],linestyle='--')
plt.axis('tight')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
# Out:
# C:\Users\rahul\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\rahul\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# Text(0.5, 0, 'False Positive Rate')

# %%
#Pickle the feature_names and classifier  
with open("C:\\Users\\Emp\\Downloads\\Work_Priya\\Final\\Opportunity_Features.pickle", "wb") as feature_file:
    pkl.dump(feature_names,feature_file)
    
with open("C:\\Users\\Emp\\Downloads\\Work_Priya\\Final\\Opportunity_LogClassifier.pickle","wb") as classifier_file:
    pkl.dump(classifier_log,classifier_file)

with open("C:\\Users\\Emp\\Downloads\\Work_Priya\\Final\\Opportunity_KSvmClassifier.pickle","wb") as classifier_file:
    pkl.dump(classifier_ksvm,classifier_file)
    
with open("C:\\Users\\Emp\\Downloads\\Work_Priya\\Final\\Opportunity_SvmClassifier.pickle","wb") as classifier_file:
    pkl.dump(classifier_svm,classifier_file)
    
with open("C:\\Users\\Emp\\Downloads\\Work_Priya\\Final\\Opportunity_NBClassifier.pickle","wb") as classifier_file:
    pkl.dump(classifier_nb,classifier_file)
    
with open("C:\\Users\\Emp\\Downloads\\Work_Priya\\Final\\Opportunity_RFClassifier.pickle","wb") as classifier_file:
    pkl.dump(regressor,classifier_file)
